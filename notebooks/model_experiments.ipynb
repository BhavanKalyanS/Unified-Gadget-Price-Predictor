# %% [markdown]
# # Model Experiments for Unified Gadget Price Predictor
#
# Use this sandbox environment to experiment with different regression models, hyperparameters, or new datasets before committing changes to `utils/train_models.py`.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# df = pd.read_csv('../datasets/mobile_prices_2026.csv')
# sns.histplot(df['Price'])
# plt.show()
